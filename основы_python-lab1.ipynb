# %% [markdown]
# #Задача 1
# Написать функцию на вход которой подается строка, состоящая из латинских букв.
# Функция должна вернуть количество гласных букв (a, e, i, o, u) в этой строке. Написать тесты для кода

# %%
def count_vowels(text):

    vowels = "aeiou"
    count = 0
    for char in text.lower():
        if char in vowels:
            count += 1
    return count


def test_count_vowels():
    assert count_vowels("hello") == 2
    assert count_vowels("world") == 1
    assert count_vowels("AEIOU") == 5
    assert count_vowels("Python") == 1
    assert count_vowels("") == 0
    assert count_vowels("bcdfg") == 0
    print("Все тесты для count_vowels пройдены!")

test_count_vowels()
# Out:
# Все тесты для count_vowels пройдены!

# %% [markdown]
# # Задача 2
# Написать функцию на вход, которой подается строка. Функция должна вернуть true, если
# каждый символ в строке встречается только 1 раз, иначе должна вернуть false. Написать тесты для кода

# %%
def is_unique_chars(string):

    return len(string) == len(set(string))


def test_is_unique_chars():
    assert is_unique_chars("abcde") == True
    assert is_unique_chars("hello") == False
    assert is_unique_chars("") == True
    assert is_unique_chars("a") == True
    assert is_unique_chars("abca") == False
    print("Все тесты для is_unique_chars пройдены!")

test_is_unique_chars()
# Out:
# Все тесты для is_unique_chars пройдены!

# %% [markdown]
# # Задача 3
# Написать функцию, которая принимает положительное число и возвращает количество
# бит равных 1 в этом числе. Написать тесты для кода

# %%
def count_bits(n):

    return bin(n).count('1')


def test_count_bits():
    assert count_bits(5) == 2  
    assert count_bits(7) == 3  
    assert count_bits(0) == 0  
    assert count_bits(1) == 1  
    assert count_bits(15) == 4 
    print("Все тесты для count_bits пройдены!")

test_count_bits()
# Out:
# Все тесты для count_bits пройдены!

# %% [markdown]
# # Задача 4
# Написать функцию, которая принимает положительное число. Функция должна вернуть то,
# сколько раз необходимо перемножать цифры числа или результат перемножения, чтобы
# получилось число состоящее из одной цифры.
# Например, для входного числа:
# · 39 функция должна вернуть 3, так как 3*9=27 => 2*7=14 => 1*4=4
# · 4 функция должна вернуть 0, так как число уже состоит из одной цифры
# · 999 функция должна вернуть 4, так как 9*9*9=729 => 7*2*9=126 => 1*2*6=12 =>
# 1*2=2. Написать тесты для кода

# %%
def magic(n):

    if n < 10:
        return 0
    
    count = 0
    while n >= 10:
        product = 1
        for digit in str(n):
            product *= int(digit)
        n = product
        count += 1
    return count


def test_magic():
    assert magic(39) == 3
    assert magic(4) == 0
    assert magic(999) == 4
    assert magic(10) == 1
    assert magic(25) == 2
    print("Все тесты для magic пройдены!")

test_magic()
# Out:
# Все тесты для magic пройдены!

# %% [markdown]
# # Задача 5
# Написать функцию, которая принимает два целочисленных вектора одинаковой длины и
# возвращает среднеквадратическое отклонение двух векторов. Написать тесты для кода

# %%
def mse(pred, true):

    if len(pred) != len(true):
        raise ValueError("Векторы должны быть одинаковой длины")
    
    squared_errors = [(p - t) ** 2 for p, t in zip(pred, true)]
    return sum(squared_errors) / len(squared_errors)


def test_mse():
    assert mse([1, 2, 3], [1, 2, 3]) == 0
    assert mse([1, 2, 3], [2, 3, 4]) == 1
    assert mse([0, 0, 0], [1, 1, 1]) == 1
    print("Все тесты для mse пройдены!")

test_mse()
# Out:
# Все тесты для mse пройдены!

# %% [markdown]
# # Задача 6
# Написать функцию, принимающая целое положительное число. Функция должна вернуть
# строку вида “(n1**p1)(n2**p2)…(nk**pk)” представляющая разложение числа на простые
# множители (если pi == 1, то выводить только ni).
# Например, для числа 86240 функция должна вернуть “(2**5)(5)(7**2)(11)”. Написать тесты для кода

# %%
def prime_factors(n):

    if n <= 1:
        return f"({n})"
    
    factors = {}
    d = 2
    while d * d <= n:
        while n % d == 0:
            factors[d] = factors.get(d, 0) + 1
            n //= d
        d += 1
    if n > 1:
        factors[n] = factors.get(n, 0) + 1
    
    result = ""
    for factor in sorted(factors.keys()):
        power = factors[factor]
        if power == 1:
            result += f"({factor})"
        else:
            result += f"({factor}**{power})"
    
    return result


def test_prime_factors():
    assert prime_factors(86240) == "(2**5)(5)(7**2)(11)"
    assert prime_factors(12) == "(2**2)(3)"
    assert prime_factors(7) == "(7)"
    assert prime_factors(1) == "(1)"
    print("Все тесты для prime_factors пройдены!")

test_prime_factors()
# Out:
# Все тесты для prime_factors пройдены!

# %% [markdown]
# # Задача 7
# Написать функцию, принимающая целое число n, задающее количество кубиков. Функция
# должна определить, можно ли из данного кол-ва кубиков построить пирамиду, то есть
# можно ли представить число n как 1^2+2^2+3^2+…+k^2. Если можно, то функция должна
# вернуть k, иначе строку “It is impossible”. Написать тесты для кода

# %%
def pyramid(number):

    total = 0
    k = 1
    while total < number:
        total += k * k
        if total == number:
            return k
        k += 1
    return "It is impossible"


def test_pyramid():
    assert pyramid(1) == 1
    assert pyramid(5) == 2
    assert pyramid(14) == 3
    assert pyramid(30) == 4
    assert pyramid(55) == 5
    assert pyramid(2) == "It is impossible"
    print("Все тесты для pyramid пройдены!")

test_pyramid()
# Out:
# Все тесты для pyramid пройдены!

# %% [markdown]
# # Задача 8
# Функция принимает на вход положительное число и определяет является ли оно сбалансированным, т.е. сумма цифр до средних равна сумме цифр после. Средними в случае нечетного числа цифр считать одну цифру, в случае четного - две средних. Написать тесты для кода

# %%
def is_balanced(number):

    digits = [int(d) for d in str(number)]
    length = len(digits)
    
    if length % 2 == 0:
        mid = length // 2
        left_sum = sum(digits[:mid-1])
        right_sum = sum(digits[mid+1:])
    else:
        mid = length // 2
        left_sum = sum(digits[:mid])
        right_sum = sum(digits[mid+1:])
    
    return left_sum == right_sum


def test_is_balanced():
    assert is_balanced(12321) == True
    assert is_balanced(123321) == True
    assert is_balanced(12345) == False
    assert is_balanced(121) == True
    assert is_balanced(1221) == True
    print("Все тесты для is_balanced пройдены!")

test_is_balanced()
# Out:
# Все тесты для is_balanced пройдены!
